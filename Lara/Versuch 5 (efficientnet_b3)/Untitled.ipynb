# %%
import torch
import torchvision
import torchvision.models as models

print("torch:", torch.__version__)
print("torchvision:", torchvision.__version__)
print("efficientnet_b3 verfügbar:", hasattr(models, "efficientnet_b3"))
# Out:
# torch: 1.12.1
# torchvision: 0.13.1
# efficientnet_b3 verfügbar: True
